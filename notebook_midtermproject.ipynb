# %% [markdown]
# ### Midterm Project

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("data/stress_detection.csv")
display(df)
# Out:
#       participant_id  day  PSS_score  Openness  Conscientiousness  \
# 0                  1    1         34  2.322732           4.332193
# 1                  1    2         37  1.761436           3.254120
# 2                  1    3         30  3.025887           1.855002
# 3                  1    4         16  1.948370           4.966676
# 4                  1    5         32  3.343484           2.065936
# ...              ...  ...        ...       ...                ...
# 2995             100   26         30  2.529821           2.339608
# 2996             100   27         33  1.319100           4.500507
# 2997             100   28         30  1.899102           3.930147
# 2998             100   29         28  1.472408           1.712893
# 2999             100   30         10  3.152789           3.633976
#
#       Extraversion  Agreeableness  Neuroticism  sleep_time  wake_time  \
# 0         1.185878       1.570213     3.782094    7.726792   5.190660
# 1         3.907281       4.072512     1.997145    7.312674   6.170717
# 2         2.045900       2.317493     3.619225    6.992060   5.318825
# 3         3.345225       1.607756     3.583524    8.886914   8.061075
# 4         3.137843       2.118061     2.567347    7.811705   7.312145
# ...            ...            ...          ...         ...        ...
# 2995      1.321208       4.204331     4.890738    8.823033   8.703758
# 2996      4.816983       2.416180     4.195933    5.260243   5.890244
# 2997      4.047799       3.163160     2.559401    6.425568   7.978066
# 2998      1.245082       4.187222     4.558563    5.453843   8.859173
# 2999      2.387994       3.853524     1.147076    5.270021   6.658582
#
#       sleep_duration  PSQI_score  call_duration  num_calls  num_sms  \
# 0           6.572069           1       3.924527         12       32
# 1           8.030168           4      58.318004          3       41
# 2           7.102420           1       4.941043          4       48
# 3           8.123294           3       0.295373         11       38
# 4           7.785143           3      22.300571         17       17
# ...              ...         ...            ...        ...      ...
# 2995        8.661936           2      59.106125          0        1
# 2996        6.456058           4      56.137068         12       17
# 2997        7.188921           3      58.102473         13       21
# 2998        7.355107           4      44.220070         17       10
# 2999        7.090551           4      36.342934         16       47
#
#       screen_on_time  skin_conductance  accelerometer  mobility_radius  \
# 0          10.703714          3.115730       0.161717         1.145179
# 1          11.012939          0.959144       0.985587         1.021133
# 2           4.877372          3.311629       1.877445         0.478179
# 3           3.462956          0.625721       0.494921         0.630549
# 4           4.861046          0.622609       1.342600         0.254090
# ...              ...               ...            ...              ...
# 2995       11.339248          4.045863       1.694037         0.859401
# 2996       10.694380          2.169768       1.657737         0.108480
# 2997        8.646478          4.995654       1.046666         0.508623
# 2998        4.086836          4.897873       1.605314         0.444716
# 2999        7.399881          3.279636       2.130984         1.347205
#
#       mobility_distance
# 0              2.196851
# 1              0.737825
# 2              0.911673
# 3              3.911418
# 4              1.605132
# ...                 ...
# 2995           4.123621
# 2996           2.242326
# 2997           2.088313
# 2998           4.741065
# 2999           4.191338
#
# [3000 rows x 20 columns]

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.dtypes
# Out:
# participant_id         int64
# day                    int64
# PSS_score              int64
# Openness             float64
# Conscientiousness    float64
# Extraversion         float64
# Agreeableness        float64
# Neuroticism          float64
# sleep_time           float64
# wake_time            float64
# sleep_duration       float64
# PSQI_score             int64
# call_duration        float64
# num_calls              int64
# num_sms                int64
# screen_on_time       float64
# skin_conductance     float64
# accelerometer        float64
# mobility_radius      float64
# mobility_distance    float64
# dtype: object

# %%
df.describe()
# Out:
#        participant_id          day    PSS_score     Openness  \
# count     3000.000000  3000.000000  3000.000000  3000.000000
# mean        50.500000    15.500000    24.701000     3.020663
# std         28.870882     8.656884     8.615781     1.159310
# min          1.000000     1.000000    10.000000     1.005003
# 25%         25.750000     8.000000    17.000000     2.024510
# 50%         50.500000    15.500000    25.000000     3.050115
# 75%         75.250000    23.000000    32.000000     4.029171
# max        100.000000    30.000000    39.000000     4.997405
#
#        Conscientiousness  Extraversion  Agreeableness  Neuroticism  \
# count        3000.000000   3000.000000    3000.000000  3000.000000
# mean            3.007883      3.002101       3.047659     2.963589
# std             1.140511      1.143507       1.161074     1.158624
# min             1.000982      1.000584       1.002206     1.000173
# 25%             2.055579      2.018888       2.043813     1.974606
# 50%             3.022064      2.985548       3.091778     2.940948
# 75%             3.981639      4.005973       4.050223     3.955566
# max             4.999137      4.997642       4.999881     4.996408
#
#         sleep_time    wake_time  sleep_duration   PSQI_score  call_duration  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean      7.002145     6.990567        7.477953     2.490333      29.717149
# std       1.160442     1.161225        0.867602     1.121454      17.563027
# min       5.003291     5.001927        6.000561     1.000000       0.002886
# 25%       6.017217     5.992499        6.710527     1.000000      14.544219
# 50%       6.978221     6.982260        7.463421     2.000000      29.465154
# 75%       8.029503     7.999644        8.222883     3.250000      44.831582
# max       8.999948     8.998371        8.999061     4.000000      59.983074
#
#          num_calls      num_sms  screen_on_time  skin_conductance  \
# count  3000.000000  3000.000000     3000.000000       3000.000000
# mean      9.362000    24.472333        6.624776          2.762022
# std       5.755055    14.553940        3.145666          1.282752
# min       0.000000     0.000000        1.006874          0.501595
# 25%       4.000000    12.000000        3.909183          1.670218
# 50%       9.000000    24.000000        6.700975          2.769001
# 75%      14.000000    37.000000        9.339519          3.843533
# max      19.000000    49.000000       11.997871          4.999104
#
#        accelerometer  mobility_radius  mobility_distance
# count    3000.000000      3000.000000        3000.000000
# mean        1.317038         0.803164           2.801677
# std         0.688541         0.402527           1.306818
# min         0.100791         0.100041           0.501622
# 25%         0.731260         0.455688           1.682666
# 50%         1.320422         0.793928           2.801065
# 75%         1.910750         1.148284           3.971290
# max         2.499946         1.499890           4.999929

# %%
df.isnull().sum()
# Out:
# participant_id       0
# day                  0
# PSS_score            0
# Openness             0
# Conscientiousness    0
# Extraversion         0
# Agreeableness        0
# Neuroticism          0
# sleep_time           0
# wake_time            0
# sleep_duration       0
# PSQI_score           0
# call_duration        0
# num_calls            0
# num_sms              0
# screen_on_time       0
# skin_conductance     0
# accelerometer        0
# mobility_radius      0
# mobility_distance    0
# dtype: int64

# %% [markdown]
# The dataset doesn't have any missing values

# %%
import matplotlib.pyplot as plt

# Plot each participant's data as a separate line
plt.figure(figsize=(12, 8))

# Loop over each participant and plot their PSS_score over days
for participant in [1, 25, 50, 75, 100]: #df['participant_id'].unique() too much data to plot
    participant_data = df[df['participant_id'] == participant]
    plt.plot(participant_data['day'], participant_data['PSS_score'], label=f'Participant {participant}', alpha=0.5)

# Labeling the plot
plt.xlabel('Day')
plt.ylabel('PSS Score')
plt.title('Daily Stress Levels for Each Participant')
plt.legend()
plt.show()

# %%
plt.hist(df['PSS_score'], bins = 6)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# The PSS Score distribution is approximately uniform.

# %% [markdown]
# ### Features importance
# Participant_id and day are technical columns that should not be considered like features influencing the PSS score. Maybe, the column day of month can impact the PSS score but I choose to not include it as feature of my models.
# <br>To get an idea about the importance of a feature to a target variable, we will measure the correlation score.

# %%
numerical = list(df.columns)
print(numerical)
#target = df["PSS_score"]
#numerical.remove("PSS_score")
numerical.remove("participant_id")
numerical.remove("day")
df = df[numerical]
df.corrwith(df["PSS_score"]).to_frame('correlation')
#df[['participant_id', 'day']].corrwith(df['PSS_score']).to_frame('correlation')
# Out:
# ['participant_id', 'day', 'PSS_score', 'Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Neuroticism', 'sleep_time', 'wake_time', 'sleep_duration', 'PSQI_score', 'call_duration', 'num_calls', 'num_sms', 'screen_on_time', 'skin_conductance', 'accelerometer', 'mobility_radius', 'mobility_distance']
#                    correlation
# PSS_score             1.000000
# Openness              0.007923
# Conscientiousness     0.011215
# Extraversion          0.010655
# Agreeableness        -0.003250
# Neuroticism           0.015813
# sleep_time           -0.018059
# wake_time            -0.004925
# sleep_duration       -0.014899
# PSQI_score           -0.021299
# call_duration         0.006049
# num_calls            -0.028919
# num_sms               0.035045
# screen_on_time        0.004377
# skin_conductance      0.016004
# accelerometer         0.004656
# mobility_radius       0.008731
# mobility_distance    -0.034954

# %% [markdown]
# Correlation score of each feature with the target variable is very small (maximum equals to 3,50 %). For this, we will keep all of the features to train the model.

# %%
import seaborn as sns
# Let's see the correlations between columns of the dataframe

corr_matrix = df.corr()

plt.figure(figsize=(10, 8))

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, square=True, fmt='.2f', linewidths=0.5)

# Title and display
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# There is no correlation between columns of the dataframe.

# %% [markdown]
# ### Data Preparation

# %%
# Renaming columns
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['pss_score', 'openness', 'conscientiousness', 'extraversion',
#        'agreeableness', 'neuroticism', 'sleep_time', 'wake_time',
#        'sleep_duration', 'psqi_score', 'call_duration', 'num_calls', 'num_sms',
#        'screen_on_time', 'skin_conductance', 'accelerometer',
#        'mobility_radius', 'mobility_distance'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
df_full_train, df_test = train_test_split (df, test_size = 0.20, random_state = 10)
df_train, df_val = train_test_split (df_full_train, test_size = 0.25, random_state = 10)
len(df_train), len(df_val), len(df_test)
# Out:
# (1800, 600, 600)

# %%
y_train = df_train["pss_score"]
y_val = df_val["pss_score"]
y_test = df_test["pss_score"]
del df_train["pss_score"]
del df_val["pss_score"]
del df_test["pss_score"]

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dv = DictVectorizer(sparse = False)

# %%
dict_train = df_train.to_dict(orient = "records")
dict_val = df_val.to_dict(orient = "records")
dict_test = df_test.to_dict(orient = "records")

# %% [markdown]
# ### Linear regression model

# %%
# Let's train a linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error

lr = LinearRegression()
X_train = dv.fit_transform(dict_train)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_train)
rmse_score = root_mean_squared_error(y_train, y_pred)
print(rmse_score)
# Out:
# 8.571092764472485

# %%
lr.coef_
# Out:
# array([ 0.23529148, -0.15825785, -0.00331923,  0.15106433,  0.16751008,
#        -0.18320274,  0.32157177,  0.23671451, -0.06504438,  0.01296836,
#        -0.10575738, -0.21166227,  0.07062839,  0.11724441, -0.16197625,
#        -0.16992655,  0.01937174])

# %%
X_val = dv.transform(dict_val)
y_pred = lr.predict(X_val)
rmse_score = root_mean_squared_error(y_val, y_pred)
print(rmse_score)
# Out:
# 8.637792746183463

# %% [markdown]
# ### Regularization of the linear regression model

# %% [markdown]
# #### Using Ridge Regression

# %%
from sklearn.linear_model import Ridge
for r in [0.001, 0.01, 0.1, 1, 10, 100]:
    ridge_model = Ridge(alpha = r)
    ridge_model.fit(X_train, y_train)
    y_pred = ridge_model.predict(X_val)
    rmse_score = root_mean_squared_error(y_val, y_pred)
    print(f'rmse score for alpha value {r} is {round(rmse_score,4)}')
# Out:
# rmse score for alpha value 0.001 is 8.6378
# rmse score for alpha value 0.01 is 8.6378
# rmse score for alpha value 0.1 is 8.6378
# rmse score for alpha value 1 is 8.6378
# rmse score for alpha value 10 is 8.6374
# rmse score for alpha value 100 is 8.6341

# %% [markdown]
# Ridge option does not provide better RMSE.

# %% [markdown]
# #### Using Lasso Regression

# %%
from sklearn.linear_model import Lasso
for r in [0.001, 0.01, 0.1, 1, 10, 100]:
    lasso_model = Lasso(alpha = r)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_val)
    rmse_score = root_mean_squared_error(y_val, y_pred)
    print(f'rmse score for alpha value {r} is {round(rmse_score,3)}')
# Out:
# rmse score for alpha value 0.001 is 8.637
# rmse score for alpha value 0.01 is 8.634
# rmse score for alpha value 0.1 is 8.604
# rmse score for alpha value 1 is 8.576
# rmse score for alpha value 10 is 8.583
# rmse score for alpha value 100 is 8.583

# %% [markdown]
# Compared to Ridge regression, Lasso regression gives slightly better RMSE score but it's not a really interesting enhancement of the model.

# %% [markdown]
# #### Using Elastic Net

# %%
from sklearn.linear_model import ElasticNet
alphas = [0.001, 0.01, 0.1, 1, 10, 100]
l1_ratio = [0.001, 0.01, 0.1, 0.5, 1]
rmse_min = 9999
alpha_best = None
l1_best = None
for alpha in alphas:
    for l1 in l1_ratio:
        elasticnet_model = ElasticNet(alpha=alpha, l1_ratio=l1)
        elasticnet_model.fit(X_train, y_train)
        y_pred = elasticnet_model.predict(X_val)
        rmse_score = root_mean_squared_error(y_val, y_pred)
        if rmse_score < rmse_min:
            rmse_min = rmse_score
            alpha_best = alpha
            l1_best = l1
        print(f'rmse score for alpha value {alpha} and l1_ratio value {l1}  is {round(rmse_score,3)}')
print(f'\n best rmse score for alpha value {alpha_best} and l1_ratio value {l1_best}  is {round(rmse_min,3)}')
# Out:
# rmse score for alpha value 0.001 and l1_ratio value 0.001  is 8.638
# rmse score for alpha value 0.001 and l1_ratio value 0.01  is 8.638
# rmse score for alpha value 0.001 and l1_ratio value 0.1  is 8.638
# rmse score for alpha value 0.001 and l1_ratio value 0.5  is 8.638
# rmse score for alpha value 0.001 and l1_ratio value 1  is 8.637
# rmse score for alpha value 0.01 and l1_ratio value 0.001  is 8.637
# rmse score for alpha value 0.01 and l1_ratio value 0.01  is 8.637
# rmse score for alpha value 0.01 and l1_ratio value 0.1  is 8.637
# rmse score for alpha value 0.01 and l1_ratio value 0.5  is 8.635
# rmse score for alpha value 0.01 and l1_ratio value 1  is 8.634
# rmse score for alpha value 0.1 and l1_ratio value 0.001  is 8.632
# rmse score for alpha value 0.1 and l1_ratio value 0.01  is 8.631
# rmse score for alpha value 0.1 and l1_ratio value 0.1  is 8.629
# rmse score for alpha value 0.1 and l1_ratio value 0.5  is 8.617
# rmse score for alpha value 0.1 and l1_ratio value 1  is 8.604
# rmse score for alpha value 1 and l1_ratio value 0.001  is 8.608
# rmse score for alpha value 1 and l1_ratio value 0.01  is 8.607
# rmse score for alpha value 1 and l1_ratio value 0.1  is 8.594
# rmse score for alpha value 1 and l1_ratio value 0.5  is 8.578
# rmse score for alpha value 1 and l1_ratio value 1  is 8.576
# rmse score for alpha value 10 and l1_ratio value 0.001  is 8.583
# rmse score for alpha value 10 and l1_ratio value 0.01  is 8.581
# rmse score for alpha value 10 and l1_ratio value 0.1  is 8.575
# rmse score for alpha value 10 and l1_ratio value 0.5  is 8.583
# rmse score for alpha value 10 and l1_ratio value 1  is 8.583
# rmse score for alpha value 100 and l1_ratio value 0.001  is 8.576
# rmse score for alpha value 100 and l1_ratio value 0.01  is 8.577
# rmse score for alpha value 100 and l1_ratio value 0.1  is 8.583
# rmse score for alpha value 100 and l1_ratio value 0.5  is 8.583
# rmse score for alpha value 100 and l1_ratio value 1  is 8.583
#
#  best rmse score for alpha value 10 and l1_ratio value 0.1  is 8.575

# %% [markdown]
# The best rmse score (8.575) with Elastic Net regression is not better than the best model using the Lasso (alpha = 1 , rmse = 8.576). For this, we will use only the Lasso regression model.

# %% [markdown]
# ### KFold Cross-Validation on Lasso regression model with tuning

# %%
def train(df_train, y_train, C=1.0):
    dicts = df_train.to_dict(orient='records')

    dv = DictVectorizer(sparse=False)
    X_train = dv.fit_transform(dicts)

    model = Lasso(alpha = C)
    model.fit(X_train, y_train)
    
    return dv, model

# %%
def predict(df, dv, model):
    dicts = df.to_dict(orient='records')

    X = dv.transform(dicts)
    y_pred = model.predict(X)

    return y_pred

# %%
from sklearn.model_selection import KFold

kfold = KFold(n_splits=5, shuffle=True, random_state=1)
alphas = [0.1, 0.2, 0.5, 0.75, 1, 5, 10, 20]

columns = list(df_full_train.columns)
columns.remove("pss_score")

for alpha in alphas :
    scores = []
    for train_idx, val_idx in kfold.split(df_full_train):
        df_train_kfold = df_full_train.iloc[train_idx]
        df_val_kfold = df_full_train.iloc[val_idx]

        y_train_kfold = df_train_kfold["pss_score"]
        y_val_kfold = df_val_kfold["pss_score"]

        dv, model = train(df_train_kfold[columns], y_train_kfold, C=alpha)
        y_pred = predict(df_val_kfold[columns], dv, model)

        rmse_score = root_mean_squared_error(y_val_kfold, y_pred)
        scores.append(rmse_score)

    print('alpha=%s %.3f +- %.3f' % (alpha, np.mean(scores), np.std(scores)))
# Out:
# alpha=0.1 8.620 +- 0.157
# alpha=0.2 8.611 +- 0.155
# alpha=0.5 8.602 +- 0.154
# alpha=0.75 8.602 +- 0.154
# alpha=1 8.603 +- 0.155
# alpha=5 8.604 +- 0.160
# alpha=10 8.604 +- 0.161
# alpha=20 8.604 +- 0.161

# %% [markdown]
# For a linear regression model, the best Lasso regression model we got with an mean rmse score of 8.602 is with alpha = 0.5 (case kfold of 5 splits).

# %% [markdown]
# ### Tree Decision Based Model

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_text

dict_train = df_train.to_dict(orient = "records")
X_train = dv.fit_transform(dict_train)
dt = DecisionTreeRegressor(criterion='squared_error', max_depth=3 , random_state= 1)
dt.fit(X_train, y_train)
print(export_text(dt, feature_names=list(dv.get_feature_names_out())))
# Out:
# |--- skin_conductance <= 4.86
# |   |--- wake_time <= 8.49
# |   |   |--- agreeableness <= 1.00
# |   |   |   |--- value: [37.00]
# |   |   |--- agreeableness >  1.00
# |   |   |   |--- value: [24.29]
# |   |--- wake_time >  8.49
# |   |   |--- call_duration <= 4.67
# |   |   |   |--- value: [20.05]
# |   |   |--- call_duration >  4.67
# |   |   |   |--- value: [26.52]
# |--- skin_conductance >  4.86
# |   |--- wake_time <= 7.89
# |   |   |--- agreeableness <= 2.09
# |   |   |   |--- value: [21.67]
# |   |   |--- agreeableness >  2.09
# |   |   |   |--- value: [29.00]
# |   |--- wake_time >  7.89
# |   |   |--- wake_time <= 8.56
# |   |   |   |--- value: [36.60]
# |   |   |--- wake_time >  8.56
# |   |   |   |--- value: [29.00]

# %% [markdown]
# Here, in the second branch (skin_conductance > 4.86), in its second branch wake_time > 7.89, it used again the same feature wake_time > or < 8.56.

# %%
y_pred = dt.predict(X_val)
rmse_score = root_mean_squared_error(y_val, y_pred)
print(rmse_score)
# Out:
# 8.729588144933544

# %% [markdown]
# The RMSE value of this decision tree model (8.73) is not better than the best score of the linear regression model (8.602).

# %% [markdown]
# ### Random Forest model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=10, random_state= 1, n_jobs=-1)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_val)
rmse_score = root_mean_squared_error(y_val, y_pred)
print(rmse_score)
# Out:
# 9.136839351402285

# %% [markdown]
# with this RF model, the RMSE score (9.137) is even worse than before. <br>
# What could be the causes ? <br>
# - n_estimators
# - Max_depth parameter
# <br> Next, we will try to tune the two parameters.

# %% [markdown]
# ### Tuning the random forest model

# %%
# Tunning the n_estimators
scores = []
for n in range(10,201,10):
    rf = RandomForestRegressor(n_estimators=n, random_state= 1, n_jobs=-1)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_val)
    score = root_mean_squared_error(y_val, y_pred)
    scores.append([n, score])
columns = ["n_estimators","rmse"]
df_scores = pd.DataFrame(scores, columns=columns)

# %%
import matplotlib.pyplot as plt
plt.plot(df_scores.n_estimators, df_scores.rmse)

# %% [markdown]
# With n_estimators of 100 and 200, we reach local minimas for RMSE value.

# %%
# Tunning the n_estimators and max_depth parameters
scores = []
d_values = [1, 2, 3 , 5, 10, 15, 20]
for d in d_values:
    for n in range(10,201,10):
        rf = RandomForestRegressor(n_estimators=n, max_depth=d, random_state= 1, n_jobs=-1)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_val)
        score = root_mean_squared_error(y_val, y_pred)
        scores.append([d, n, score])
columns = ["max_depth", "n_estimators","rmse"]
df_scores = pd.DataFrame(scores, columns=columns)

# %%
df_scores.groupby('max_depth').rmse.agg('mean')
# Out:
# max_depth
# 1     8.593748
# 2     8.604762
# 3     8.610984
# 5     8.622480
# 10    8.703782
# 15    8.750716
# 20    8.746782
# Name: rmse, dtype: float64

# %% [markdown]
# With the Random forest model, we did not get a really better score that with the linear model.

# %% [markdown]
# ### Using XGBoost

# %%
import xgboost as xgb

# %%
features = list(dv.get_feature_names_out())
dtrain = xgb.DMatrix(X_train, label = y_train, feature_names = features)
dval = xgb.DMatrix(X_val, label = y_val, feature_names = features)
watchlist = [(dtrain, 'train'), (dval, 'val')]

# %%
def parse_xgb_output(output, parameter_value):
    results = []

    for line in output.stdout.strip().split('\n'):
        it_line, train_line, val_line = line.split('\t')

        it = int(it_line.strip('[]'))
        train = float(train_line.split(':')[1])
        val = float(val_line.split(':')[1])

        results.append((parameter_value, it, train, val))
    
    columns = ['parameter', 'num_iter', 'train_rmse', 'val_rmse']
    df_results = pd.DataFrame(results, columns=columns)
    return df_results

# %%
# %%capture output

eta_value = 0.05

xgb_params = {
    'eta': eta_value, 
    'max_depth': 3,
    'min_child_weight': 1,
    
    'objective': 'reg:squarederror',
    'nthread': 8,
    
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=100,
                  evals=watchlist)

# %%
parse_xgb_output(output, eta_value).sort_values("val_rmse",ascending=True)
# Out:
#     parameter  num_iter  train_rmse  val_rmse
# 4        0.05         4     8.55600   8.57758
# 6        0.05         6     8.53614   8.57893
# 3        0.05         3     8.56742   8.57899
# 7        0.05         7     8.52557   8.58045
# 14       0.05        14     8.46267   8.58047
# ..        ...       ...         ...       ...
# 94       0.05        94     7.85410   8.65499
# 97       0.05        97     7.83332   8.65509
# 99       0.05        99     7.82416   8.65571
# 98       0.05        98     7.82976   8.65634
# 95       0.05        95     7.84789   8.65714
#
# [100 rows x 4 columns]

# %%
y_pred = model.predict(dval)
root_mean_squared_error(y_val, y_pred)
# Out:
# 8.655710801818215

# %% [markdown]
# Tuning XGBoost

# %% [markdown]
# tuning eta parameter

# %%
columns = ['parameter', 'num_iter', 'train_rmse', 'val_rmse']
df_scores_parameter = pd.DataFrame(columns=columns)

# %%
# %%capture output
# Tuning eta

eta_value = 0.1 #we iterate manually on [0.05, 0.1, 0.3, 0.5, 0.7]

xgb_params = {
    'eta': eta_value, 
    'max_depth': 3,
    'min_child_weight': 1,
    
    'objective': 'reg:squarederror',
    'nthread': 8,
    
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=100,
                evals=watchlist)

# %%
df_scores_parameter = pd.concat([df_scores_parameter, parse_xgb_output(output, eta_value).sort_values("val_rmse",ascending=True).head(1)], ignore_index = True)
# Out:
# C:\Users\ElSenior\AppData\Local\Temp\ipykernel_19228\3096594894.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_scores_parameter = pd.concat([df_scores_parameter, parse_xgb_output(output, eta_value).sort_values("val_rmse",ascending=True).head(1)], ignore_index = True)

# %%
df_scores_parameter.head(10)
# Out:
#    parameter num_iter  train_rmse  val_rmse
# 0        0.1        3     8.52683   8.57611

# %% [markdown]
# Iterating on eta on values [0.05, 0.1, 0.3, 0.5, 0.7], the eta value that gives the best rmse score on validation set is 0.10 with a RMSE score of 8.576. <br>

# %% [markdown]
# tuning max_depth

# %%
columns = ['parameter', 'num_iter', 'train_rmse', 'val_rmse']
df_scores_parameter = pd.DataFrame(columns=columns)

# %%
# %%capture output
# Tuning max_depth

parameter = 4 #we iterate manually on [1, 2, 3, 4, 5, 10, 15, 20]

xgb_params = {
    'eta': 0.1, 
    'max_depth': parameter,
    'min_child_weight': 1,
    
    'objective': 'reg:squarederror',
    'nthread': 8,
    
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=100,
                evals=watchlist)

# %%
df_scores_parameter = pd.concat([df_scores_parameter, parse_xgb_output(output, parameter).sort_values("val_rmse",ascending=True).head(1)], ignore_index = True)
# Out:
# C:\Users\ElSenior\AppData\Local\Temp\ipykernel_19228\3512640947.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_scores_parameter = pd.concat([df_scores_parameter, parse_xgb_output(output, parameter).sort_values("val_rmse",ascending=True).head(1)], ignore_index = True)

# %%
df_scores_parameter.head(10)
# Out:
#   parameter num_iter  train_rmse  val_rmse
# 0         4        1     8.52543    8.5838

# %% [markdown]
# Tuning the max_depth parameter, the best value to use is max_depth = 3 (at the third iteration) with a RMSE score on validation dataset of 8.576

# %% [markdown]
# Tuning the num_boost_round parameter

# %%
columns = ['parameter', 'val_rmse']
df_scores_parameter = []

# %%
# %%capture output
# Tuning num_boost_round
for parameter in range(1,21,1):
    xgb_params = {
        'eta': 0.1, 
        'max_depth': 3,
        'min_child_weight': 1,
        
        'objective': 'reg:squarederror',
        'nthread': 8,
        
        'seed': 1,
        'verbosity': 1,
    }

    model = xgb.train(xgb_params, dtrain, num_boost_round=parameter,
                    evals=watchlist)

    y_pred = model.predict(dval)
    rmse_score = root_mean_squared_error(y_val, y_pred)
    df_scores_parameter.append([parameter, rmse_score])

# %%
columns = ['parameter', 'val_rmse']
df_scores_parameter = pd.DataFrame(df_scores_parameter, columns = columns)
df_scores_parameter.head(20)
# Out:
#     parameter  val_rmse
# 0           1  8.586071
# 1           2  8.581412
# 2           3  8.580006
# 3           4  8.576112
# 4           5  8.578501
# 5           6  8.582151
# 6           7  8.585824
# 7           8  8.585053
# 8           9  8.595702
# 9          10  8.602173
# 10         11  8.602565
# 11         12  8.604838
# 12         13  8.600580
# 13         14  8.601893
# 14         15  8.601347
# 15         16  8.605327
# 16         17  8.596291
# 17         18  8.600568
# 18         19  8.595610
# 19         20  8.597140

# %% [markdown]
# At first list of valueswe get close values for parameter in  [5, 10, 20]. Next, we tried close value to the last interval 1 to 20. <br>
# The best value of the parameter that gives the best rmse score is 4, with an rmse score on validation dataset of 8.576.

# %% [markdown]
# ### Comparing the three models

# %% [markdown]
# - XGBOOST (eta: 0.10, max_depth: 3, num_boost_round = 4) -> RMSE score on validation data = 8.576
# - Random Forest -> RMSE score on validation data = 8.593
# - Decision Tree model -> RMSE score on validation data = 8.73
# - Linear regression model -> RMSE score on validation data = 8.602
# <br>
#
# <br>The model that will be used next is the XGBOOST Model

# %% [markdown]
# #### Training the chosen model on the full_train

# %%
df_full_train.columns
# Out:
# Index(['pss_score', 'openness', 'conscientiousness', 'extraversion',
#        'agreeableness', 'neuroticism', 'sleep_time', 'wake_time',
#        'sleep_duration', 'psqi_score', 'call_duration', 'num_calls', 'num_sms',
#        'screen_on_time', 'skin_conductance', 'accelerometer',
#        'mobility_radius', 'mobility_distance'],
#       dtype='object')

# %%
y_full_train = df_full_train["pss_score"]
del df_full_train["pss_score"]
dict_full_train = df_full_train.to_dict(orient = "records")
X_full_train = dv.transform(dict_full_train)

X_test = dv.transform(dict_test)

dfull_train = xgb.DMatrix(X_full_train, label = y_full_train, feature_names = features)
dtest = xgb.DMatrix(X_test, label = y_test, feature_names = features)

# %%
xgb_params = {
    'eta': 0.1, 
    'max_depth': 3,
    'min_child_weight': 1,
    
    'objective': 'reg:squarederror',
    'nthread': 8,
    
    'seed': 1,
    'verbosity': 1,
}
model = xgb.train(xgb_params, dfull_train, num_boost_round= 4,
                evals=watchlist)
# Out:
# [0]	train-rmse:8.59265	val-rmse:8.56164
# [1]	train-rmse:8.57720	val-rmse:8.55163
# [2]	train-rmse:8.56175	val-rmse:8.53228
# [3]	train-rmse:8.54912	val-rmse:8.51532

# %%
y_pred = model.predict(dtest)

rmse_score = root_mean_squared_error(y_test, y_pred)
rmse_score
# Out:
# 8.668242149166405

# %% [markdown]
# The RMSE score of  the xgboost model trained of full_data set and tested on the test data set is 8.668.

# %% [markdown]
# #### Save the model

# %%
import pickle

# %%
with open('train.bin', 'wb') as f_out :
    pickle.dump((dv, model), f_out)

# %% [markdown]
# ### Remarks :
# The original dataset seems to be not a good dataset due maybe ot its origin of data (not real data). For this cause, I could not compare between the the performance of possible models seen, even with tunning parameters.
